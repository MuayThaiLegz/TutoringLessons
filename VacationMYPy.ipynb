# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# !pip install hvplot
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 23.7 MB/s eta 0:00:00
# ...

# %%
# Dependencies and Setup
import hvplot.pandas
import holoviews as hv

import pandas as pd
import requests

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID         City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0         faya  18.3851   42.4509     22.06        35          21
# 1        1      farsund  58.0948    6.8047     13.30       100           0
# 2        2  new norfolk -42.7826  147.0587     11.72        58          12
# 3        3    jamestown  42.0970  -79.2353      5.77        77         100
# 4        4      lanzhou  36.0564  103.7922     14.53        48          59
#
#    Wind Speed Country        Date
# 0        2.60      SA  1666108228
# 1        7.65      NO  1666108228
# 2        1.34      AU  1666108230
# 3        9.77      US  1666107934
# 4        1.20      CN  1666108230

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# import plotly.express as px

# fig = px.scatter_geo(city_data_df,
#                      lat='Lat',
#                      lon='Lng',
#                      hover_name='City',
#                      size='Humidity',
#                      template='plotly',
#                      projection='natural earth',
#                      title='City Humidity Levels')

# fig.show()

# %%
import holoviews as hv
from holoviews import opts
# hv.extension('bokeh')

# %%
import holoviews as hv
from holoviews import opts
# hv.extension('bokeh')

# hv.extension('matplotlib')

# %%
# %%capture --no-display
# %env HV_DOC_HTML=true
# hv.extension('bokeh')
plot = city_data_df.hvplot.scatter(x='Lng',
                                   y='Lat',
                                   hover_cols=['City', 'Humidity'],
                                   size='Humidity',  # Points are sized by humidity
                                   by='Country',  # Optionally color points by Country
                                   height=500,
                                   width=800,
                                   title='City Humidity Levels')


display(plot)
# Out:
# :NdOverlay   [Country]
#    :Scatter   [Lng]   (Lat,Humidity,City)

# %%
# %%capture --no-display

# Configure the map plot
# YOUR CODE HERE

# Display the map
# YOUR CODE HERE

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Step 1: Narrow down cities based on criteria
filtered_cities_df = city_data_df[
    (city_data_df['Cloudiness'] == 0) &
    (city_data_df['Max Temp'] <= 25) & #(city_data_df['Max Temp'] >= 20) &
    (city_data_df['Humidity'] < 70) &
    (city_data_df['Wind Speed'] < 5)
]

# Step 2: Drop any rows with null values
filtered_cities_df = filtered_cities_df.dropna()

# Step 3: Display sample data
filtered_cities_df
# Out:
#      City_ID            City      Lat       Lng  Max Temp  Humidity  \
# 63        63           banda  25.4833   80.3333     24.62        52
# 90        90    saint george  37.1041 -113.5841     13.33        44
# 96        96         zhangye  38.9342  100.4517     11.11        16
# 115      115      cedar city  37.6775 -113.0619     14.11        49
# 141      141         brenham  30.1669  -96.3977     14.47        40
# 152      152         kahului  20.8947 -156.4700     23.80        60
# 174      174           avera  33.1940  -82.5271     12.53        26
# 240      240     tikaitnagar  26.9500   81.5833     23.56        59
# 268      268         chengde  40.9725  117.9361      5.17        26
# 293      293   kamen-rybolov  44.7481  132.0403      2.69        55
# 303      303   alice springs -23.7000  133.8833     15.75        63
# 331      331      swan river  52.1058 -101.2676      0.94        40
# 340      340   santa rosalia  27.3167 -112.2833     24.62        56
# ...

# %%
# Narrow down cities that fit criteria and drop any results with null values
# YOUR CODE HERE

# Drop any rows with null values
# YOUR CODE HERE

# Display sample data
# YOUR CODE HERE

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
hotel_df = filtered_cities_df[['City', 'Country', 'Lat', 'Lng', 'Humidity']].copy()

hotel_df['Hotel Name'] = ""

hotel_df.head()
# Out:
#              City Country      Lat       Lng  Humidity Hotel Name
# 63          banda      IN  25.4833   80.3333        52
# 90   saint george      US  37.1041 -113.5841        44
# 96        zhangye      CN  38.9342  100.4517        16
# 115    cedar city      US  37.6775 -113.0619        49
# 141       brenham      US  30.1669  -96.3977        40

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
# YOUR CODE HERE

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
# YOUR CODE HERE

# Display sample data
# YOUR CODE HERE

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# OpenWeatherMap API Key
weather_api_key = "87d59f0a92e58e227419e9c78240ba60"

# Geoapify API Key
geoapify_key = "63ef97d09b83423d96165458a5ebf41e"

# %%
# Set parameters to search for a hotel
radius = 10000  # Search within 5 km radius
params = {
    'apiKey': geoapify_key,  # Replace with your actual API key
    'radius': radius
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # Get latitude, longitude from the DataFrame
    lat = row['Lat']
    lon = row['Lng']

    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:${lon},${lat},${radius}"
    params["bias"] = f"proximity:${lon},${lat}"

    # Set base URL
    # base_url = "https://api.geoapify.com/v2/place-details?id=id%3D514d368a517c511e40594bfd7b574ec84740f00103f90135335d1c00000000920313416e61746f6d697363686573204d757365756d"
    base_url = "https://api.geoapify.com/v2/place-details/"

    # Make an API request using the params dictionary
    response = requests.get(base_url, params=params)

    # Convert the API response to JSON format
    name_address = response.json()

    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"

    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df.head()
# Out:
# Starting hotel search
# banda - nearest hotel: No hotel found
# saint george - nearest hotel: No hotel found
# zhangye - nearest hotel: No hotel found
# cedar city - nearest hotel: No hotel found
# brenham - nearest hotel: No hotel found
# kahului - nearest hotel: No hotel found
# avera - nearest hotel: No hotel found
# tikaitnagar - nearest hotel: No hotel found
# chengde - nearest hotel: No hotel found
# kamen-rybolov - nearest hotel: No hotel found
# alice springs - nearest hotel: No hotel found
# swan river - nearest hotel: No hotel found
# santa rosalia - nearest hotel: No hotel found
# narwar - nearest hotel: No hotel found
# saint anthony - nearest hotel: No hotel found
# roebourne - nearest hotel: No hotel found
# saint-francois - nearest hotel: No hotel found
# stolac - nearest hotel: No hotel found
# aktau - nearest hotel: No hotel found
# yangliuqing - nearest hotel: No hotel found
# tieling - nearest hotel: No hotel found
# juegang - nearest hotel: No hotel found
# ...

# %%
# import requests
# from requests.structures import CaseInsensitiveDict

# url = "https://api.geoapify.com/v2/place-details?id=id%3D514d368a517c511e40594bfd7b574ec84740f00103f90135335d1c00000000920313416e61746f6d697363686573204d757365756d&apiKey=63ef97d09b83423d96165458a5ebf41e"

# headers = CaseInsensitiveDict()
# headers["Accept"] = "application/json"

# resp = requests.get(url, headers=headers)

# %%
# Set parameters to search for a hotel
radius = # YOUR CODE HERE
params = {
    # YOUR CODE HERE
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    # YOUR CODE HERE

    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = # YOUR CODE HERE
    params["bias"] = # YOUR CODE HERE

    # Set base URL
    base_url = "https://api.geoapify.com/v2/place-details"


    # Make and API request using the params dictionaty
    name_address = # YOUR CODE HERE

    # Convert the API response to JSON format
    name_address = # YOUR CODE HERE

    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"

    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# ---------------------------------------------------------------------------
# SyntaxError                               Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/IPython/core/compilerop.py in ast_parse(self, source, filename, symbol)
#      99         Arguments are exactly the same as ast.parse (in the standard library),
#     100         and are passed to the built-in compile function."""
# --> 101         return compile(source, filename, symbol, self.flags | PyCF_ONLY_AST, 1)
#     102
#     103     def reset_compiler_flags(self):
#
# SyntaxError: invalid syntax (<ipython-input-78-d456699d9c26>, line 2)

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
# YOUR CODE HERE

# Display the map
# YOUR CODE HERE
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)

# %%
# %%capture --no-display
# %env HV_DOC_HTML=true
# hv.extension('bokeh')
plot = city_data_df.hvplot.scatter(x='Lng',
                                   y='Lat',
                                   hover_cols=['City', 'Hotel Name','Humidity'],
                                   size='Humidity',  # Points are sized by humidity
                                   by='Country',  # Optionally color points by Country
                                   height=500,
                                   width=800,
                                   title='City Humidity Levels')


display(plot)
